# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)
color =sns.color_palette("viridis")
sns.lineplot(data=data,palette="viridis")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)
sns.scatterplot(data=data,x="Profit",y="Product Category",hue="Unit Price")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)
sns.scatterplot(data=data,x="Sales",y="Profit",hue="Unit Price")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)
color =sns.color_palette("viridis")
sns.lineplot(data=data,x="Product Category",y="Sales")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)
color =sns.color_palette("viridis")
sns.barplot(data=data,palette="viridis")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)
color =sns.color_palette("viridis")
sns.barplot(data=data,palette="viridis")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = sns.load_dataset("tips")
sns.scatterplot(data=data,x="total_bill",y="tip",hue="time")
print(data)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = sns.load_dataset("taxis")
print(data)
sns.scatterplot(data=data,x="passengers",y="distance",hue="fare")
plt.show()
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = sns.load_dataset("taxis")
print(data)
gp = data.groupby("tip").agg({"passengers":"mean"})
sns.heatmap(gp)
plt.show()
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)
sns.countplot(data = data, x="Order Quantity",)
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)

sns.countplot(data = data, x="Product Category")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)

sns.violinplot(data = data, x="Profit")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)

sns.pairplot(data=data,)
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)

sns.stripplot(data=data,x="Ship Mode",y="Sales")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)

sns.boxplot(data=data,x="Unit Price",y="Profit")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
data = pd.read_excel("order.xlsx")
print(data)

sns.catplot(data=data,x="Sales",y="Profit")
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = sns.load_dataset("tips")
print(data)
a = sns.relplot(data = data, x ="tip",y = "total_bill", hue="time" )
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = sns.load_dataset("tips")
print(data)
a = sns.swarmplot(data = data, x ="tip",y = "total_bill", hue="day" )
plt.show()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
data = sns.load_dataset("tips")
print(data)
a = sns.kdeplot(data = data, x ="tip",y = "total_bill", hue="day", multiple="stack" )
plt.show()
