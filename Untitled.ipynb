# %%
import pandas as pd

# %%
data = {"Name":["Pankaj","Pavan","Priti","Durgesh","Ishan"],"Age":[18,26,24,24,12],"Salary":[15000,28000,22000,25000,12000]}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Salary
# 0   Pankaj   18   15000
# 1    Pavan   26   28000
# 2    Priti   24   22000
# 3  Durgesh   24   25000
# 4    Ishan   12   12000

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)
plt.plot(df["Sales"],df["Profit"]  )
print(df)
plt.show()
# Out:
#       Order ID Order Date  Order Quantity       Sales       Ship Mode  \
# 0            3 2010-10-13               6    261.5400     Regular Air
# 1            6 2012-02-20               2      6.9300     Regular Air
# 2           32 2011-07-15              26   2808.0800     Regular Air
# 3           32 2011-07-15              24   1761.4000  Delivery Truck
# 4           32 2011-07-15              23    160.2335     Regular Air
# ...        ...        ...             ...         ...             ...
# 1002      7171 2011-02-13              17    303.1865     Regular Air
# 1003      7174 2012-03-10              10    141.9200     Regular Air
# 1004      7175 2010-02-07              10    748.2500  Delivery Truck
# 1005      7203 2009-01-08              25  21752.0100     Regular Air
# 1006      7239 2011-06-29              50   6206.1600     Regular Air
#
#         Profit  Unit Price       Customer Name Customer Segment  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
gp = data.groupby(["Sales","Product Category","Unit Price"]).agg({"Profit":"count"})
print(gp)
# Out:
#                                       Profit
# Sales    Product Category Unit Price
# 2.24     Office Supplies  1.48             1
# 5.68     Office Supplies  4.76             1
# 6.13     Office Supplies  2.89             1
# 6.93     Office Supplies  2.08             1
# 9.25     Office Supplies  4.13             1
# ...                                      ...
# 22319.58 Technology       549.99           1
# 23281.05 Technology       599.99           1
# 24105.87 Technology       2036.48          1
# 25409.63 Office Supplies  1270.99          1
# 45923.76 Technology       6783.02          1
#
# [999 rows x 1 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)
colors = ["Red","Blue","Green","Orange","Purple"]
plt.bar(df["Order Date"],df["Profit"],color="lime")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)
colors = ["Red","Blue","Green","Orange","Purple"]
plt.scatter(df["Order Date"],df["Profit"],color="red")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)
colors = ["Red","Blue","Green","Orange","Purple"]
plt.stem(df["Order Date"],df["Profit"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)

plt.hist(df["Profit"],bins=10)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)

plt.step(df["Order Date"],df["Profit"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)

plt.stackplot(df["Sales"],df["Profit"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("order.xlsx")
df = pd.DataFrame(data)

plt.boxplot(df["Unit Price"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv("Book1.csv")
print(data)
plt.hist()
# Out:
#     SR no           Student   Age  Class
# 0     1.0     Pavan Ahirwar  17.0   12.0
# 1     2.0     Ishan Ahirwar  10.0    7.0
# 2     3.0   Durgesh Ahirwar  17.0   12.0
# 3     4.0    Pankaj Ahirwar  15.0   10.0
# 4     5.0    Ayushi Ahirwar   6.0    2.0
# 5     6.0   Anshika Ahirwar   5.0    1.0
# 6     7.0   Shiksha Ahirwar  12.0    8.0
# 7     8.0  Sharansh Ahirwar   4.0    0.0
# 8     9.0  Suryansh Ahirwar  15.0   10.0
# 9    10.0    Harish Ahirwar  17.0   12.0
# 10    NaN               NaN   NaN    NaN

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_excel("Electoral.xlsx")
print(data)
# Out:
#       Date of Purchase                  Purchaser Name Denomination
# 0           2019-04-12             A B C INDIA LIMITED     1,00,000
# 1           2019-04-12             A B C INDIA LIMITED     1,00,000
# 2           2019-04-12             A B C INDIA LIMITED    10,00,000
# 3           2019-04-12             A B C INDIA LIMITED    10,00,000
# 4           2019-04-12             A B C INDIA LIMITED     1,00,000
# ...                ...                             ...          ...
# 18866       2024-01-11  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18867       2024-01-11  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18868       2024-01-11  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18869       2024-01-11  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
# 18870       2024-01-11  WESTWELL GASES PRIVATE LIMITED  1,00,00,000
#
# [18871 rows x 3 columns]

# %%
import pandas as pd
data = pd.read_excel("Electoral Bonds.xlsx")
print(data)
# Out:
#      Date of\nEncashment               Name of the Political Party  \
# 0             2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1             2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2             2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3             2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4             2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...                  ...                                       ...
# 7577          2021-10-12   PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 7578          2021-10-12   PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 7579          2021-10-12   PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 7580          2021-10-12   PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 7581          2021-10-12   PRESIDENT, ALL INDIA CONGRESS COMMITTEE
#
#      Denomination
# 0       10,00,000
# 1       10,00,000
# 2     1,00,00,000
# 3       10,00,000
# 4       10,00,000
# ...           ...
# 7577     1,00,000
# ...
